# %%
import pandas as pd
import numpy as np

# %%
path = 'C:/Users/bacho/Desktop/municipios/fuerocomunmunicipios.csv'
df = pd.read_csv(path, encoding='latin', low_memory=False)
df.head()
# Out:
#    state_code  mun_code  year  month                  crime  \
# 0           1         1  2011      1  DELITOS PATRIMONIALES
# 1           1         1  2011      2  DELITOS PATRIMONIALES
# 2           1         1  2011      3  DELITOS PATRIMONIALES
# 3           1         1  2011      4  DELITOS PATRIMONIALES
# 4           1         1  2011      5  DELITOS PATRIMONIALES
#
#                 category                type             subtype  count  \
# 0  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   44.0
# 1  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   43.0
# 2  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   34.0
# 3  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   21.0
# 4  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   35.0
#
#    population
# 0      811483
# 1      812551
# 2      813619
# 3      814686
# 4      815754

# %%
path = 'C:/Users/bacho/Desktop/municipios/fuerocomunmunicipios.csv'
df = pd.read_csv(path, encoding='latin', low_memory=False)
df.head()
# Out:
#    state_code  mun_code  year  month                  crime  \
# 0           1         1  2011      1  DELITOS PATRIMONIALES
# 1           1         1  2011      2  DELITOS PATRIMONIALES
# 2           1         1  2011      3  DELITOS PATRIMONIALES
# 3           1         1  2011      4  DELITOS PATRIMONIALES
# 4           1         1  2011      5  DELITOS PATRIMONIALES
#
#                 category                type             subtype  count  \
# 0  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   44.0
# 1  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   43.0
# 2  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   34.0
# 3  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   21.0
# 4  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   35.0
#
#    population
# 0      811483
# 1      812551
# 2      813619
# 3      814686
# 4      815754

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 10 columns):
# state_code    1048575 non-null int64
# mun_code      1048575 non-null int64
# year          1048575 non-null int64
# month         1048575 non-null int64
# crime         1048575 non-null object
# category      1048575 non-null object
# type          1048575 non-null object
# subtype       1048575 non-null object
# count         522497 non-null float64
# population    1048575 non-null int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 80.0+ MB

# %%
df.shape
# Out:
# (1048575, 10)

# %%
df.shape[0]
# Out:
# 1048575

# %%
df.shape[1]
# Out:
# 10

# %%
df.columns.values.tolist()
# Out:
# ['state_code',
#  'mun_code',
#  'year',
#  'month',
#  'crime',
#  'category',
#  'type',
#  'subtype',
#  'count',
#  'population']

# %%
df.dtypes
# Out:
# state_code      int64
# mun_code        int64
# year            int64
# month           int64
# crime          object
# category       object
# type           object
# subtype        object
# count         float64
# population      int64
# dtype: object

# %%
df.isnull().any().any()
# Out:
# True

# %%
df.columns[df.isnull().any()].tolist()
# Out:
# ['count']

# %%
len(pd.isnull(df).any(1).nonzero()[0].tolist())
# Out:
# C:\Users\bacho\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   """Entry point for launching an IPython kernel.
# 526078

# %%
pd.isnull(df).any(1).nonzero()[0].tolist()[0:5]
# Out:
# C:\Users\bacho\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   """Entry point for launching an IPython kernel.
# [941, 946, 2661, 2741, 2781]

# %%
df.describe()
# Out:
#          state_code      mun_code          year         month          count  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  522497.000000
# mean   7.820991e+00  3.224044e+01  2.012200e+03  6.099318e+00       3.942038
# std    2.555086e+00  2.911003e+01  9.798139e-01  3.505405e+00      25.995808
# min    1.000000e+00  1.000000e+00  2.011000e+03  1.000000e+00       0.000000
# 25%    7.000000e+00  1.000000e+01  2.011000e+03  3.000000e+00       0.000000
# 50%    8.000000e+00  2.400000e+01  2.012000e+03  6.000000e+00       0.000000
# 75%    1.000000e+01  4.400000e+01  2.013000e+03  9.000000e+00       0.000000
# max    1.200000e+01  1.190000e+02  2.014000e+03  1.200000e+01    1188.000000
#
#          population
# count  1.048575e+06
# mean   9.191384e+04
# std    2.157411e+05
# min    1.092000e+03
# 25%    9.583000e+03
# 50%    2.582000e+04
# 75%    6.466400e+04
# max    1.830454e+06

# %%
df.loc[[0]]
# Out:
#    state_code  mun_code  year  month                  crime  \
# 0           1         1  2011      1  DELITOS PATRIMONIALES
#
#                 category                type             subtype  count  \
# 0  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   44.0
#
#    population
# 0      811483

# %%
df.loc[30:33]
# Out:
#     state_code  mun_code  year  month                  crime  \
# 30           1         1  2013      7  DELITOS PATRIMONIALES
# 31           1         1  2013      8  DELITOS PATRIMONIALES
# 32           1         1  2013      9  DELITOS PATRIMONIALES
# 33           1         1  2013     10  DELITOS PATRIMONIALES
#
#                  category                type             subtype  count  \
# 30  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   47.0
# 31  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   48.0
# 32  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   39.0
# 33  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   42.0
#
#     population
# 30      842391
# 31      843374
# 32      844358
# 33      845341

# %%
df.drop([0,24,51], axis=0).head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-5ec113d23858> in <module>
# ----> 1 df.drop([0,24,51], axis=0).head()
#       2
#
# NameError: name 'df' is not defined

# %%
df.drop([0,24,51], axis=0).head()
# Out:
#    state_code  mun_code  year  month                  crime  \
# 1           1         1  2011      2  DELITOS PATRIMONIALES
# 2           1         1  2011      3  DELITOS PATRIMONIALES
# 3           1         1  2011      4  DELITOS PATRIMONIALES
# 4           1         1  2011      5  DELITOS PATRIMONIALES
# 5           1         1  2011      6  DELITOS PATRIMONIALES
#
#                 category                type             subtype  count  \
# 1  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   43.0
# 2  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   34.0
# 3  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   21.0
# 4  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   35.0
# 5  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   43.0
#
#    population
# 1      812551
# 2      813619
# 3      814686
# 4      815754
# 5      816822

# %%
df.drop(df.index[1:5], axis=0).head(10)
# Out:
#     state_code  mun_code  year  month                  crime  \
# 0            1         1  2011      1  DELITOS PATRIMONIALES
# 5            1         1  2011      6  DELITOS PATRIMONIALES
# 6            1         1  2011      7  DELITOS PATRIMONIALES
# 7            1         1  2011      8  DELITOS PATRIMONIALES
# 8            1         1  2011      9  DELITOS PATRIMONIALES
# 9            1         1  2011     10  DELITOS PATRIMONIALES
# 10           1         1  2011     11  DELITOS PATRIMONIALES
# 11           1         1  2011     12  DELITOS PATRIMONIALES
# 12           1         1  2012      1  DELITOS PATRIMONIALES
# 13           1         1  2012      2  DELITOS PATRIMONIALES
#
#                  category                type             subtype  count  \
# 0   DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   44.0
# 5   DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   43.0
# 6   DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   42.0
# 7   DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   37.0
# 8   DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   36.0
# 9   DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   37.0
# 10  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   31.0
# 11  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   27.0
# 12  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   50.0
# 13  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   52.0
#
#     population
# 0       811483
# 5       816822
# 6       817861
# 7       818900
# 8       819939
# 9       820978
# 10      822017
# 11      823056
# 12      824094
# 13      825133

# %%
df[100:].head() #df.tail(-100) )
# Out:
#      state_code  mun_code  year  month                  crime  \
# 100           1         1  2012      9  DELITOS PATRIMONIALES
# 101           1         1  2012     10  DELITOS PATRIMONIALES
# 102           1         1  2012     11  DELITOS PATRIMONIALES
# 103           1         1  2012     12  DELITOS PATRIMONIALES
# 104           1         1  2013      1  DELITOS PATRIMONIALES
#
#                   category     type        subtype  count  population
# 100  DELITOS PATRIMONIALES  DESPOJO  CON VIOLENCIA    0.0      832319
# 101  DELITOS PATRIMONIALES  DESPOJO  CON VIOLENCIA    0.0      833329
# 102  DELITOS PATRIMONIALES  DESPOJO  CON VIOLENCIA    0.0      834339
# 103  DELITOS PATRIMONIALES  DESPOJO  CON VIOLENCIA    0.0      835348
# 104  DELITOS PATRIMONIALES  DESPOJO  CON VIOLENCIA    0.0      836358

# %%
df.crime.values
# Out:
# array(['DELITOS PATRIMONIALES', 'DELITOS PATRIMONIALES',
#        'DELITOS PATRIMONIALES', ..., 'HOMICIDIOS', 'HOMICIDIOS',
#        'HOMICIDIOS'], dtype=object)

# %%
df.crime.unique()
# Out:
# array(['DELITOS PATRIMONIALES', 'DELITOS SEXUALES', 'HOMICIDIOS',
#        'LESIONES', 'OTROS DELITOS', 'PRIV. DE LA LIBERTAD (SECUESTRO)',
#        'ROBOS'], dtype=object)

# %%
df.crime.value_counts()
# Out:
# ROBOS                               587486
# HOMICIDIOS                          127331
# LESIONES                            127024
# DELITOS PATRIMONIALES               111426
# OTROS DELITOS                        63512
# DELITOS SEXUALES                     15918
# PRIV. DE LA LIBERTAD (SECUESTRO)     15878
# Name: crime, dtype: int64

# %%
df.agg(['count', 'size', 'nunique'])
# Out:
#          state_code  mun_code     year    month    crime  category     type  \
# count       1048575   1048575  1048575  1048575  1048575   1048575  1048575
# size        1048575   1048575  1048575  1048575  1048575   1048575  1048575
# nunique          12       118        4       12        7        10       18
#
#          subtype    count  population
# count    1048575   522497     1048575
# size     1048575  1048575     1048575
# nunique       29      672       14002

# %%
df.groupby('state_code').agg(['count', 'size', 'nunique']).stack()
# Out:
#                     mun_code    year   month   crime  category    type  \
# state_code
# 1          count       29040   29040   29040   29040     29040   29040
#            size        29040   29040   29040   29040     29040   29040
#            nunique        11       4      12       7        10      18
# 2          count       13200   13200   13200   13200     13200   13200
#            size        13200   13200   13200   13200     13200   13200
#            nunique         5       4      12       7        10      18
# 3          count       13200   13200   13200   13200     13200   13200
#            size        13200   13200   13200   13200     13200   13200
#            nunique         5       4      12       7        10      18
# 4          count       29040   29040   29040   29040     29040   29040
#            size        29040   29040   29040   29040     29040   29040
#            nunique        11       4      12       7        10      18
# 5          count      100320  100320  100320  100320    100320  100320
#            size       100320  100320  100320  100320    100320  100320
#            nunique        38       4      12       7        10      18
# 6          count       26400   26400   26400   26400     26400   26400
#            size        26400   26400   26400   26400     26400   26400
#            nunique        10       4      12       7        10      18
# 7          count      311520  311520  311520  311520    311520  311520
#            size       311520  311520  311520  311520    311520  311520
#            nunique       118       4      12       7        10      18
# 8          count      176880  176880  176880  176880    176880  176880
#            size       176880  176880  176880  176880    176880  176880
#            nunique        67       4      12       7        10      18
# 9          count       42108   42108   42108   42108     42108   42108
#            size        42108   42108   42108   42108     42108   42108
#            nunique        16       4      12       7        10      18
# 10         count      102960  102960  102960  102960    102960  102960
#            size       102960  102960  102960  102960    102960  102960
#            nunique        39       4      12       7        10      18
# 11         count      121440  121440  121440  121440    121440  121440
#            size       121440  121440  121440  121440    121440  121440
#            nunique        46       4      12       7        10      18
# 12         count       82467   82467   82467   82467     82467   82467
#            size        82467   82467   82467   82467     82467   82467
#            nunique        32       4      12       7        10      18
#
#                     subtype   count  population
# state_code
# 1          count      29040   28904       29040
#            size       29040   29040       29040
#            nunique       29     219         440
# 2          count      13200    5392       13200
#            size       13200   13200       13200
#            nunique       29     521         200
# 3          count      13200   10200       13200
#            size       13200   13200       13200
#            nunique       29     215         200
# 4          count      29040   28973       29040
#            size       29040   29040       29040
#            nunique       29      37         439
# 5          count     100320   72473      100320
#            size      100320  100320      100320
#            nunique       29     216        1482
# 6          count      26400   26400       26400
#            size       26400   26400       26400
#            nunique       29     113         400
# 7          count     311520   77854      311520
#            size      311520  311520      311520
#            nunique       29     123        4505
# 8          count     176880   17750      176880
#            size      176880  176880      176880
#            nunique       29     336        2405
# 9          count      42108   42072       42108
#            size       42108   42108       42108
#            nunique       29     402         635
# 10         count     102960    8578      102960
#            size      102960  102960      102960
#            nunique       29     229        1485
# 11         count     121440  121436      121440
#            size      121440  121440      121440
#            nunique       29     342        1809
# 12         count      82467   82465       82467
#            size       82467   82467       82467
#            nunique       29     240        1195

# %%
df.groupby('state_code').agg(['count', 'size', 'nunique'])
# Out:
#            mun_code                    year                   month          \
#               count    size nunique   count    size nunique   count    size
# state_code
# 1             29040   29040      11   29040   29040       4   29040   29040
# 2             13200   13200       5   13200   13200       4   13200   13200
# 3             13200   13200       5   13200   13200       4   13200   13200
# 4             29040   29040      11   29040   29040       4   29040   29040
# 5            100320  100320      38  100320  100320       4  100320  100320
# 6             26400   26400      10   26400   26400       4   26400   26400
# 7            311520  311520     118  311520  311520       4  311520  311520
# 8            176880  176880      67  176880  176880       4  176880  176880
# 9             42108   42108      16   42108   42108       4   42108   42108
# 10           102960  102960      39  102960  102960       4  102960  102960
# 11           121440  121440      46  121440  121440       4  121440  121440
# 12            82467   82467      32   82467   82467       4   82467   82467
#
#                      crime  ...    type subtype                   count  \
#            nunique   count  ... nunique   count    size nunique   count
# state_code                  ...
# 1               12   29040  ...      18   29040   29040      29   28904
# 2               12   13200  ...      18   13200   13200      29    5392
# 3               12   13200  ...      18   13200   13200      29   10200
# 4               12   29040  ...      18   29040   29040      29   28973
# 5               12  100320  ...      18  100320  100320      29   72473
# 6               12   26400  ...      18   26400   26400      29   26400
# 7               12  311520  ...      18  311520  311520      29   77854
# 8               12  176880  ...      18  176880  176880      29   17750
# 9               12   42108  ...      18   42108   42108      29   42072
# 10              12  102960  ...      18  102960  102960      29    8578
# 11              12  121440  ...      18  121440  121440      29  121436
# 12              12   82467  ...      18   82467   82467      29   82465
#
#                            population
#               size nunique      count    size nunique
# state_code
# 1            29040     219      29040   29040     440
# 2            13200     521      13200   13200     200
# 3            13200     215      13200   13200     200
# 4            29040      37      29040   29040     439
# 5           100320     216     100320  100320    1482
# 6            26400     113      26400   26400     400
# 7           311520     123     311520  311520    4505
# 8           176880     336     176880  176880    2405
# 9            42108     402      42108   42108     635
# 10          102960     229     102960  102960    1485
# 11          121440     342     121440  121440    1809
# 12           82467     240      82467   82467    1195
#
# [12 rows x 27 columns]

# %%
df_sample = df.sample(frac=0.05, random_state=1)
df_sample.head()
# Out:
#          state_code  mun_code  year  month          crime            category  \
# 1045953          12        31  2011      6       LESIONES            LESIONES
# 358409            7        56  2011     10          ROBOS  ROBO EN CARRETERAS
# 875012           11        12  2013      1          ROBOS          ROBO COMUN
# 555046            8        13  2011      7       LESIONES            LESIONES
# 272972            7        24  2012      1  OTROS DELITOS       OTROS DELITOS
#
#                     type              subtype  count  population
# 1045953         CULPOSAS      CON ARMA BLANCA    0.0        6351
# 358409     SIN VIOLENCIA  A CAMIONES DE CARGA    NaN       11688
# 875012     CON VIOLENCIA     A TRANSPORTISTAS    0.0       28460
# 555046          CULPOSAS      CON ARMA BLANCA    NaN       11378
# 272972   OTROS SEXUALES        OTROS SEXUALES    NaN       11196

# %%
df.shape
# Out:
# (1048575, 10)

# %%
df_sample.shape
# Out:
# (52429, 10)

# %%
df_sample.groupby('state_code').agg(['count', 'size', 'nunique']).stack()
# Out:
#                     mun_code   year  month  crime  category   type  subtype  \
# state_code
# 1          count        1400   1400   1400   1400      1400   1400     1400
#            size         1400   1400   1400   1400      1400   1400     1400
#            nunique        11      4     12      7        10     18       29
# 2          count         664    664    664    664       664    664      664
#            size          664    664    664    664       664    664      664
#            nunique         5      4     12      7        10     18       29
# 3          count         679    679    679    679       679    679      679
#            size          679    679    679    679       679    679      679
#            nunique         5      4     12      7        10     18       29
# 4          count        1415   1415   1415   1415      1415   1415     1415
#            size         1415   1415   1415   1415      1415   1415     1415
#            nunique        11      4     12      7        10     18       29
# 5          count        5026   5026   5026   5026      5026   5026     5026
#            size         5026   5026   5026   5026      5026   5026     5026
#            nunique        38      4     12      7        10     18       29
# 6          count        1288   1288   1288   1288      1288   1288     1288
#            size         1288   1288   1288   1288      1288   1288     1288
#            nunique        10      4     12      7        10     18       29
# 7          count       15795  15795  15795  15795     15795  15795    15795
#            size        15795  15795  15795  15795     15795  15795    15795
#            nunique       118      4     12      7        10     18       29
# 8          count        8856   8856   8856   8856      8856   8856     8856
#            size         8856   8856   8856   8856      8856   8856     8856
#            nunique        67      4     12      7        10     18       29
# 9          count        2092   2092   2092   2092      2092   2092     2092
#            size         2092   2092   2092   2092      2092   2092     2092
#            nunique        16      4     12      7        10     18       29
# 10         count        5030   5030   5030   5030      5030   5030     5030
#            size         5030   5030   5030   5030      5030   5030     5030
#            nunique        39      4     12      7        10     18       29
# 11         count        5928   5928   5928   5928      5928   5928     5928
#            size         5928   5928   5928   5928      5928   5928     5928
#            nunique        46      4     12      7        10     18       29
# 12         count        4256   4256   4256   4256      4256   4256     4256
#            size         4256   4256   4256   4256      4256   4256     4256
#            nunique        32      4     12      7        10     18       29
#
#                     count  population
# state_code
# 1          count     1393        1400
#            size      1400        1400
#            nunique     52         424
# 2          count      276         664
#            size       664         664
#            nunique    113         194
# 3          count      528         679
#            size       679         679
#            nunique     48         195
# 4          count     1413        1415
#            size      1415        1415
#            nunique     15         427
# 5          count     3689        5026
#            size      5026        5026
#            nunique     73        1436
# 6          count     1288        1288
#            size      1288        1288
#            nunique     35         389
# 7          count     4005       15795
#            size     15795       15795
#            nunique     47        4378
# 8          count      892        8856
#            size      8856        8856
#            nunique     68        2330
# 9          count     2092        2092
#            size      2092        2092
#            nunique    159         610
# 10         count      414        5030
#            size      5030        5030
#            nunique     52        1440
# 11         count     5928        5928
#            size      5928        5928
#            nunique     88        1731
# 12         count     4256        4256
#            size      4256        4256
#            nunique     50        1153

# %%
df_dropped = df.dropna(subset=['count'])
df_dropped.head()
# Out:
#    state_code  mun_code  year  month                  crime  \
# 0           1         1  2011      1  DELITOS PATRIMONIALES
# 1           1         1  2011      2  DELITOS PATRIMONIALES
# 2           1         1  2011      3  DELITOS PATRIMONIALES
# 3           1         1  2011      4  DELITOS PATRIMONIALES
# 4           1         1  2011      5  DELITOS PATRIMONIALES
#
#                 category                type             subtype  count  \
# 0  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   44.0
# 1  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   43.0
# 2  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   34.0
# 3  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   21.0
# 4  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   35.0
#
#    population
# 0      811483
# 1      812551
# 2      813619
# 3      814686
# 4      815754

# %%
df_dropped.shape
# Out:
# (522497, 10)

# %%
df_copy = df.copy()
df_copy.head()
# Out:
#    state_code  mun_code  year  month                  crime  \
# 0           1         1  2011      1  DELITOS PATRIMONIALES
# 1           1         1  2011      2  DELITOS PATRIMONIALES
# 2           1         1  2011      3  DELITOS PATRIMONIALES
# 3           1         1  2011      4  DELITOS PATRIMONIALES
# 4           1         1  2011      5  DELITOS PATRIMONIALES
#
#                 category                type             subtype  count  \
# 0  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   44.0
# 1  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   43.0
# 2  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   34.0
# 3  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   21.0
# 4  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   35.0
#
#    population
# 0      811483
# 1      812551
# 2      813619
# 3      814686
# 4      815754

# %%
df_copy.shape
# Out:
# (1048575, 10)

# %%
df_dropped['count'].dtype
# Out:
# dtype('float64')

# %%
df_dropped['count'].mean()
# Out:
# 3.942037944715472

# %%
df_copy['count'].fillna(value=np.round(df['count'].mean(),decimals=0), inplace=True)

# %%
df_copy.agg(['count', 'size', 'nunique'])
# Out:
#          state_code  mun_code     year    month    crime  category     type  \
# count       1048575   1048575  1048575  1048575  1048575   1048575  1048575
# size        1048575   1048575  1048575  1048575  1048575   1048575  1048575
# nunique          12       118        4       12        7        10       18
#
#          subtype    count  population
# count    1048575  1048575     1048575
# size     1048575  1048575     1048575
# nunique       29      672       14002

# %%
df_sample = df_copy.sample(frac=0.05, random_state=1)
df_sample.head()
# Out:
#          state_code  mun_code  year  month          crime            category  \
# 1045953          12        31  2011      6       LESIONES            LESIONES
# 358409            7        56  2011     10          ROBOS  ROBO EN CARRETERAS
# 875012           11        12  2013      1          ROBOS          ROBO COMUN
# 555046            8        13  2011      7       LESIONES            LESIONES
# 272972            7        24  2012      1  OTROS DELITOS       OTROS DELITOS
#
#                     type              subtype  count  population
# 1045953         CULPOSAS      CON ARMA BLANCA    0.0        6351
# 358409     SIN VIOLENCIA  A CAMIONES DE CARGA    4.0       11688
# 875012     CON VIOLENCIA     A TRANSPORTISTAS    0.0       28460
# 555046          CULPOSAS      CON ARMA BLANCA    4.0       11378
# 272972   OTROS SEXUALES        OTROS SEXUALES    4.0       11196

# %%
list(df.crime.unique())
# Out:
# ['DELITOS PATRIMONIALES',
#  'DELITOS SEXUALES',
#  'HOMICIDIOS',
#  'LESIONES',
#  'OTROS DELITOS',
#  'PRIV. DE LA LIBERTAD (SECUESTRO)',
#  'ROBOS']

# %%
keys = list(df.crime.unique())
vals = range(1,8)
crime_map = dict(zip(keys, vals))
crime_map
# Out:
# {'DELITOS PATRIMONIALES': 1,
#  'DELITOS SEXUALES': 2,
#  'HOMICIDIOS': 3,
#  'LESIONES': 4,
#  'OTROS DELITOS': 5,
#  'PRIV. DE LA LIBERTAD (SECUESTRO)': 6,
#  'ROBOS': 7}

# %%
df_copy['crime_cat'] = df.crime.map(crime_map)
df_copy.head()
# Out:
#    state_code  mun_code  year  month                  crime  \
# 0           1         1  2011      1  DELITOS PATRIMONIALES
# 1           1         1  2011      2  DELITOS PATRIMONIALES
# 2           1         1  2011      3  DELITOS PATRIMONIALES
# 3           1         1  2011      4  DELITOS PATRIMONIALES
# 4           1         1  2011      5  DELITOS PATRIMONIALES
#
#                 category                type             subtype  count  \
# 0  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   44.0
# 1  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   43.0
# 2  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   34.0
# 3  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   21.0
# 4  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   35.0
#
#    population  crime_cat
# 0      811483          1
# 1      812551          1
# 2      813619          1
# 3      814686          1
# 4      815754          1

# %%
list(df_copy.crime_cat.unique())
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
from sklearn import preprocessing

df_normalized = df.dropna().copy()
min_max_scaler = preprocessing.MinMaxScaler()
np_scaled = min_max_scaler.fit_transform(df_normalized['population'].values.reshape(-1,1))
df_normalized['population_norm'] = np_scaled.reshape(-1,1)
df_normalized.head()
# Out:
#    state_code  mun_code  year  month                  crime  \
# 0           1         1  2011      1  DELITOS PATRIMONIALES
# 1           1         1  2011      2  DELITOS PATRIMONIALES
# 2           1         1  2011      3  DELITOS PATRIMONIALES
# 3           1         1  2011      4  DELITOS PATRIMONIALES
# 4           1         1  2011      5  DELITOS PATRIMONIALES
#
#                 category                type             subtype  count  \
# 0  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   44.0
# 1  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   43.0
# 2  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   34.0
# 3  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   21.0
# 4  DELITOS PATRIMONIALES  ABUSO DE CONFIANZA  ABUSO DE CONFIANZA   35.0
#
#    population  population_norm
# 0      811483         0.442991
# 1      812551         0.443575
# 2      813619         0.444159
# 3      814686         0.444742
# 4      815754         0.445326

# %%
df['state_code'].mean()
# Out:
# 7.820991345397325

# %%
df['state_code'][df['month'] == 1].mean()
# Out:
# 7.821151700660812

# %%
df.groupby(['state_code', 'year']).count()
# Out:
#                  mun_code  month  crime  category   type  subtype  count  \
# state_code year
# 1          2011      8712   8712   8712      8712   8712     8712   8708
#            2012      8712   8712   8712      8712   8712     8712   8585
#            2013      8712   8712   8712      8712   8712     8712   8708
#            2014      2904   2904   2904      2904   2904     2904   2903
# 2          2011      3960   3960   3960      3960   3960     3960   1500
#            2012      3960   3960   3960      3960   3960     3960   1739
#            2013      3960   3960   3960      3960   3960     3960   1512
#            2014      1320   1320   1320      1320   1320     1320    641
# 3          2011      3960   3960   3960      3960   3960     3960   3960
#            2012      3960   3960   3960      3960   3960     3960   3960
#            2013      3960   3960   3960      3960   3960     3960   1660
#            2014      1320   1320   1320      1320   1320     1320    620
# 4          2011      8712   8712   8712      8712   8712     8712   8646
#            2012      8712   8712   8712      8712   8712     8712   8712
#            2013      8712   8712   8712      8712   8712     8712   8711
#            2014      2904   2904   2904      2904   2904     2904   2904
# 5          2011     30096  30096  30096     30096  30096    30096  21143
#            2012     30096  30096  30096     30096  30096    30096  20524
#            2013     30096  30096  30096     30096  30096    30096  23218
#            2014     10032  10032  10032     10032  10032    10032   7588
#                                                               month
#                                       variance_population      mean
# category                         year
# DELITOS PATRIMONIALES            2011       228937.805994  6.563197
#                                  2012       223981.701600  6.552221
#                                  2013       239074.823798  6.448317
#                                  2014       192136.155943  2.410019
# DELITOS SEXUALES (VIOLACION)     2011       191190.449466  6.440909
#                                  2012       219331.264052  6.677686
#                                  2013       258858.032402  6.479508
#                                  2014       134905.619913  2.453488
# HOMICIDIOS                       2011       193677.197995  6.617600
#                                  2012       226411.933097  6.571583
#                                  2013       224412.615441  6.502350
#                                  2014       224028.126466  2.508451
# LESIONES                         2011       196362.830711  6.536269
#                                  2012       231627.574151  6.495612
#                                  2013       210372.943699  6.536870
#                                  2014       241328.033377  2.519417
# OTROS DELITOS                    2011       231697.052713  6.486574
#                                  2012       236607.363057  6.596927
#                                  2013       194546.675930  6.470948
#                                  2014       183435.721267  2.555944
# PRIV. DE LA LIBERTAD (SECUESTRO) 2011       219121.139602  6.406780
#                                  2012       196458.262355  6.674157
#                                  2013       234013.675414  6.439024
#                                  2014       263725.150303  2.393617
# ROBO COMUN                       2011       220196.836073  6.440885
#                                  2012       228532.925350  6.582598
#                                  2013       226458.670227  6.459850
#                                  2014       235515.402356  2.494614
# ROBO DE GANADO (ABIGEATO)        2011       238927.382190  6.187755
#                                  2012       233393.983482  6.036585
#                                  2013       206740.280624  6.859438
#                                  2014       234809.142954  2.526316
# ROBO EN CARRETERAS               2011       220837.699367  6.478861
#                                  2012       225599.399389  6.558664
#                                  2013       195684.966965  6.552961
#                                  2014       230240.556147  2.486019
# ROBO EN INSTITUCIONES BANCARIAS  2011       204971.340197  6.429872
#                                  2012       206276.213218  6.495142
#                                  2013       200588.070883  6.475891
#                                  2014       188392.432273  2.456914

# %%
<ipython-input-1-c70ad54ae3dd> in <module>()
----> 1 df_sample.head()

NameError: name 'df_sample' is not defined
# Out:
#   File "<ipython-input-43-4523129dc05d>", line 1
#     <ipython-input-1-c70ad54ae3dd> in <module>()
#     ^
# SyntaxError: invalid syntax

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

ax1 = plt.axes()  # standard axes
ax2 = plt.axes([0.65, 0.65, 0.2, 0.2])

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4],
                   xticklabels=[], ylim=(-1.2, 1.2))
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4],
                   ylim=(-1.2, 1.2))

x = np.linspace(0, 10)
ax1.plot(np.sin(x))
ax2.plot(np.cos(x))

# %%
for i in range(1, 7):
    plt.subplot(2, 3, i)
    plt.text(0.5, 0.5, str((2, 3, i)),
             fontsize=18, ha='center')

# %%
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(1, 7):
    ax = fig.add_subplot(2, 3, i)
    ax.text(0.5, 0.5, str((2, 3, i)),
           fontsize=18, ha='center')

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')

# %%
for i in range(2):
    for j in range(3):
        ax[i, j].text(0.5, 0.5, str((i, j)),
                      fontsize=18, ha='center')
fig

# %%
# Create some normally distributed data
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 3000).T

# Set up the axes with gridspec
fig = plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)

# scatter points on the main axes
main_ax.plot(x, y, 'ok', markersize=3, alpha=0.2)

# histogram on the attached axes
x_hist.hist(x, 40, histtype='stepfilled',
            orientation='vertical', color='gray')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled',
            orientation='horizontal', color='gray')
y_hist.invert_xaxis()

# %%
df_sample['year'] = df_sample['year'].astype('int64')

df_sample.plot(kind='scatter',x='year',y='population')

# %%
df_copy.plot(kind='scatter',x='year',y='population')

# %%
df_sample.plot(kind='scatter',x='population',y='count')

# %%
df_sample.plot(kind='scatter',x='population',y='crime_cat')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'crime_cat'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-d01dbdfaa073> in <module>
# ----> 1 df_sample.plot(kind='scatter',x='population',y='crime_cat')
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     736         if kind in self._dataframe_kinds:
#     737             if isinstance(data, ABCDataFrame):
# --> 738                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     739             else:
#     740                 raise ValueError(
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59                 ax = plt.gca()
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
# ---> 61     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
#      62     plot_obj.generate()
#      63     plot_obj.draw()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in __init__(self, data, x, y, s, c, **kwargs)
#     928             # the handling of this argument later
#     929             s = 20
# --> 930         super().__init__(data, x, y, s=s, **kwargs)
#     931         if is_integer(c) and not self.data.columns.holds_integer():
#     932             c = self.data.columns[c]
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in __init__(self, data, x, y, **kwargs)
#     869         if len(self.data[x]._get_numeric_data()) == 0:
#     870             raise ValueError(self._kind + " requires x column to be numeric")
# --> 871         if len(self.data[y]._get_numeric_data()) == 0:
#     872             raise ValueError(self._kind + " requires y column to be numeric")
#     873
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'crime_cat'

# %%
plt.hist(df_sample['crime'])
plt.xlabel('Crime')
plt.ylabel('Frequency')
plt.title('Frequency of Crime')
# Out:
# Text(0.5, 1.0, 'Frequency of Crime')

# %%
plt.hist(df_sample['crime_cat'])
plt.xlabel('Crime')
plt.ylabel('Frequency')
plt.title('Frequency of Crime')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'crime_cat'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-4357c462e5d6> in <module>
# ----> 1 plt.hist(df_sample['crime_cat'])
#       2 plt.xlabel('Crime')
#       3 plt.ylabel('Frequency')
#       4 plt.title('Frequency of Crime')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'crime_cat'

# %%
plt.hist(df_sample['crime_cat'])
plt.xlabel('Crime')
plt.ylabel('Frequency')
plt.title('Frequency of Crime')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'crime_cat'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-5da322a66273> in <module>
# ----> 1 plt.hist(df_sample['crime_cat'])
#       2 plt.xlabel('Crime')
#       3 plt.ylabel('Frequency')
#       4 plt.title('Frequency of Crime')
#       5
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'crime_cat'

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
ax0, ax1 = axes.flatten()
ax0.hist(df_sample['crime_cat'])
ax1.hist(df_sample['crime'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'crime_cat'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-b56749857650> in <module>
#       1 fig, axes = plt.subplots(nrows=1, ncols=2)
#       2 ax0, ax1 = axes.flatten()
# ----> 3 ax0.hist(df_sample['crime_cat'])
#       4 ax1.hist(df_sample['crime'])
#       5 plt.show()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'crime_cat'

# %%
#plt.boxplot(df_sample['crime_cat'])
plt.boxplot(df_sample['month'], showmeans=True, meanline=True)
plt.ylabel('Crime categories')
plt.title('Box Plot of Crime categories')
# Out:
# Text(0.5, 1.0, 'Box Plot of Crime categories')
